# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
df = pd.read_csv('Downloads/Credit.csv').iloc[:,1:7]
df
# Out:
#       Income  Limit  Rating  Cards  Age  Education
# 0     14.891   3606     283      2   34         11
# 1    106.025   6645     483      3   82         15
# 2    104.593   7075     514      4   71         11
# 3    148.924   9504     681      3   36         11
# 4     55.882   4897     357      2   68         16
# ..       ...    ...     ...    ...  ...        ...
# 395   12.096   4100     307      3   32         13
# 396   13.364   3838     296      5   65         17
# 397   57.872   4171     321      5   67         12
# 398   37.728   2525     192      1   44         13
# 399   18.701   5524     415      5   64          7
#
# [400 rows x 6 columns]

# %% [markdown]
# ### 1.Predictor: Income

# %%
df.plot(kind='scatter', x = 'Limit', y = 'Income')

# %%
plot = sns.lmplot(y='Income', x='Limit', data=df)

# %%
r1 = sns.residplot('Limit', 'Income', data = df)
r1.set(xlabel='Lot Size', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Lot Size')]

# %%
lin_reg_limit = LinearRegression()
lin_reg_limit.fit(df.drop('Income', axis=1), df.iloc[:,0])
lin_reg_limit
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg_limit.coef_
# Out:
# array([ 0.002278  ,  0.14475197, -1.49673919,  0.19871908, -0.0942278 ])

# %%
lin_reg_limit.intercept_
# Out:
# -22.315288297741866

# %% [markdown]
# ### 2.Predictor: Rating

# %%
df.plot(kind='scatter', x = 'Limit', y = 'Rating')

# %%
plot = sns.lmplot(y='Rating', x='Limit', data=df)

# %%
r1 = sns.residplot('Limit', 'Rating', data = df)
r1.set(xlabel='Limit', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Limit')]

# %%
lin_reg_rating = LinearRegression()
lin_reg_rating.fit(df.drop('Rating', axis=1), df.iloc[:,2])
lin_reg_rating
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg_rating.coef_
# Out:
# array([ 3.35485393e-02,  6.63804553e-02,  4.85381863e+00,  7.78467717e-04,
#        -2.18197621e-01])

# %%
lin_reg_rating.intercept_
# Out:
# 27.607942369861348

# %% [markdown]
# ###  3.Predictor: Cards

# %%
df.plot(kind='scatter', x = 'Limit', y = 'Cards')

# %%
plot = sns.lmplot(y='Cards', x='Limit', data=df)

# %%
r1 = sns.residplot('Limit', 'Cards', data = df)
r1.set(xlabel='Limit', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Limit')]

# %%
lin_reg_cards = LinearRegression()
lin_reg_cards.fit(df.drop('Rating', axis=1), df.iloc[:,3])
lin_reg_cards
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg_cards.coef_
# Out:
# array([-5.75901264e-17,  1.20091985e-17,  1.00000000e+00,  3.59359720e-17,
#         3.47004556e-16])

# %%
lin_reg_cards.intercept_
# Out:
# -6.261657858885883e-14

# %% [markdown]
# ### 4.Predictor: Age

# %%
df.plot(kind='scatter', x = 'Limit', y = 'Age')

# %%
plot = sns.lmplot(y='Age', x='Limit', data=df)

# %%
r1 = sns.residplot('Limit', 'Age', data = df)
r1.set(xlabel='Limit', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Limit')]

# %%
lin_reg_age = LinearRegression()
lin_reg_age.fit(df.drop('Age', axis=1), df.iloc[:,4])
lin_reg_age
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg_age.coef_
# Out:
# array([ 0.12711602, -0.0009288 ,  0.00214858,  0.61008325,  0.06040086])

# %%
lin_reg_age.intercept_
# Out:
# 50.93856347512765

# %% [markdown]
# ### 5Predictor: Education

# %%
df.plot(kind='scatter', x = 'Limit', y = 'Education')

# %%
plot = sns.lmplot(y='Education', x='Limit', data=df)

# %%
r1 = sns.residplot('Limit', 'Education', data = df)
r1.set(xlabel='Limit', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Limit')]

# %%
lin_reg_education = LinearRegression()
lin_reg_education.fit(df.drop('Education', axis=1), df.iloc[:,5])
lin_reg_education
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg_education.coef_
# Out:
# array([-0.00203832,  0.00135224, -0.02036551, -0.01943516,  0.00204257])

# %%
lin_reg_education.intercept_
# Out:
# 14.310827734027246
